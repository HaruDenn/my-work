# %% [markdown]
# # Tugas 7&8

# %%
import cv2
import datetime

# Load the Haar cascade files
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
smile_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_smile.xml')

# Start webcam
cap = cv2.VideoCapture(1)

if not cap.isOpened():
    print("Error: Could not access the webcam.")
    exit()

print("Press 'q' to quit.")

while True:
    # Capture frame from webcam
    ret, frame = cap.read()
    if not ret:
        print("Error: Unable to read frame from webcam.")
        break

    # Convert to grayscale for Haar cascade
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for (x, y, w, h) in faces:
        # Draw rectangle around the face
        cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)

        # Region of interest for smile detection
        roi_gray = gray[y:y + h, x:x + w]
        roi_color = frame[y:y + h, x:x + w]

        # Detect smile
        smiles = smile_cascade.detectMultiScale(roi_gray, scaleFactor=1.8, minNeighbors=20, minSize=(25, 25))

        for (sx, sy, sw, sh) in smiles:
            # Draw rectangle around the smile
            cv2.rectangle(roi_color, (sx, sy), (sx + sw, sy + sh), (0, 255, 0), 2)

            # Capture and save image
            timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
            filename = f"smile_{timestamp}.png"
            cv2.imwrite(filename, frame)
            print(f"Image saved: {filename}")

    # Display the video feed
    cv2.imshow('Smile Detector', frame)

    # Break the loop with 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# Press 'q' to quit.
# Image saved: smile_20241122_215100.png
# Image saved: smile_20241122_215100.png
# Image saved: smile_20241122_215100.png
# Image saved: smile_20241122_215100.png
# Image saved: smile_20241122_215100.png
# Image saved: smile_20241122_215100.png
# Image saved: smile_20241122_215100.png
# Image saved: smile_20241122_215101.png
# Image saved: smile_20241122_215101.png
# Image saved: smile_20241122_215101.png
# Image saved: smile_20241122_215101.png
# Image saved: smile_20241122_215101.png
# Image saved: smile_20241122_215105.png
# Image saved: smile_20241122_215105.png
# Image saved: smile_20241122_215105.png
# Image saved: smile_20241122_215105.png
# Image saved: smile_20241122_215105.png
# Image saved: smile_20241122_215106.png
# Image saved: smile_20241122_215109.png
# Image saved: smile_20241122_215109.png
# Image saved: smile_20241122_215109.png
# Image saved: smile_20241122_215109.png
# Image saved: smile_20241122_215109.png
# Image saved: smile_20241122_215109.png
# Image saved: smile_20241122_215109.png
# Image saved: smile_20241122_215113.png
# Image saved: smile_20241122_215113.png
# Image saved: smile_20241122_215122.png
# Image saved: smile_20241122_215122.png
# Image saved: smile_20241122_215122.png
# Image saved: smile_20241122_215122.png
# Image saved: smile_20241122_215122.png
# Image saved: smile_20241122_215122.png
# Image saved: smile_20241122_215123.png
# Image saved: smile_20241122_215123.png
